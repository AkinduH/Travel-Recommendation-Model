# %% [markdown]
# # Import libraries and data

# %%
import numpy as np 
import pandas as pd 
import re
from fuzzywuzzy import fuzz # for string matching
from fuzzywuzzy import process # for string matching
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from tqdm import tqdm  # Import tqdm for progress logging
import logging
from textblob import TextBlob
import google.generativeai as genai
from collections import defaultdict
import time

# %%
places_df = pd.read_csv('Places Dataset.xlsx - places_final_dataset.csv')
users_df = pd.read_csv('Visitors Preference Dataset.xlsx - user_data_version_3_10K_Users.csv')

# %% [markdown]
# # Exploratory data analysis

# %%
places_df.head()
# Out:
#                              name       lat        lng  \
# 0                Arugam Bay Beach  6.840408  81.836848
# 1                   Mirissa Beach  5.944703  80.459161
# 2  Weligama Beach (surf and stay)  5.972486  80.435714
# 3                        Ahangama  5.973975  80.362159
# 4                 Hikkaduwa Beach  6.137727  80.099060
#
#              formatted_address  rating  user_ratings_total  \
# 0  Arugam Bay Beach, Sri Lanka     4.8              1591.0
# 1           Mirissa, Sri Lanka     4.6              1748.0
# 2          Weligama, Sri Lanka     4.4               325.0
# 3          Ahangama, Sri Lanka     NaN                 NaN
# 4   Hikkaduwa Beach, Sri Lanka     4.7              1438.0
#
#                                       latest_reviews
# 0  ['Arugam Bay Beach is a surfer's paradise! I s...
# 1  ['Mirissa Beach is truly a gem on Sri LankaÃ¢Â...
# 2  ['Weligama Beach is a fantastic spot for both ...
# 3  ['Ahangama was a bit disappointing for me as a...
# 4  ['Hikkaduwa Beach is a delightful escape for s...

# %%
users_df.head()
# Out:
#    User ID              Name                         Email  \
# 0        1    Jennifer Quinn    jennifer.quinn@example.com
# 1        2       Emily Perry       emily.perry@example.com
# 2        3  Danielle Mcbride  danielle.mcbride@example.com
# 3        4   Angelica Wilson   angelica.wilson@example.com
# 4        5     Laurie Powers     laurie.powers@example.com
#
#                                 Preferred Activities  \
# 0  ['cycling', 'historical monuments', 'village h...
# 1  ['butterfly watching', 'hot springs', 'wildlif...
# 2  ['sea cruises', 'themed parks', 'craft worksho...
# 3              ['fishing', 'hot springs', 'sailing']
# 4     ['history tours', 'sailing', 'literary tours']
#
#                   Bucket list destinations Sri Lanka
# 0  ['Polonnaruwa', 'Hatton', 'Anuradhapura', 'Ell...
# 1  ['Madunagala Hot Water Spring', 'Wilpattu Nati...
# 2  ['Mirissa Beach', 'Negombo Lagoon', 'Batadomba...
# 3  ['Maha Oya Hot Water Springs', 'Colombo Port C...
# 4  ['Negombo Lagoon', 'Colombo Port City', 'Galle...

# %%
#Function to analyze data
def customDescription(df: pd.DataFrame, numeric_only: bool = False):
    if numeric_only:
        df = df.select_dtypes(include=np.number)
    
    desc = pd.DataFrame(index=df.columns.to_list())
    desc['type'] = df.dtypes
    desc['count'] = df.count()
    desc['nunique'] = df.nunique()
    desc['null'] = df.isnull().sum()
    
    # Handle numeric columns separately
    if not df.select_dtypes(include=np.number).empty:
        numeric_desc = df.describe().T.drop(columns=['count','std','25%','50%','75%'], axis=1)
        for col in df.select_dtypes(include=np.number).columns:
            desc.loc[col, 'mean'] = numeric_desc.loc[col, 'mean']
            desc.loc[col, 'min'] = numeric_desc.loc[col, 'min']
            desc.loc[col, 'max'] = numeric_desc.loc[col, 'max']
    
    # Handle non-numeric columns separately
    if not df.select_dtypes(exclude=np.number).empty:
        non_numeric_desc = df.select_dtypes(exclude=np.number).describe().T
        desc = pd.concat([desc, non_numeric_desc.drop(columns=['count', 'unique', 'top', 'freq'], axis=1, errors='ignore')], axis=1)
    
    return desc

# %%
customDescription(users_df)
# Out:
#                                       type  count  nunique  null    mean  min  \
# User ID                              int64  10000    10000     0  5000.5  1.0
# Name                                object  10000     9419     0     NaN  NaN
# Email                               object  10000     9369     0     NaN  NaN
# Preferred Activities                object  10000     9830     0     NaN  NaN
# Bucket list destinations Sri Lanka  object  10000     9995     0     NaN  NaN
#
#                                         max
# User ID                             10000.0
# Name                                    NaN
# Email                                   NaN
# Preferred Activities                    NaN
# Bucket list destinations Sri Lanka      NaN

# %%
customDescription(places_df)
# Out:
#                        type  count  nunique  null         mean        min  \
# name                 object    411      398     0          NaN        NaN
# lat                 float64    410      402     1     7.304668   5.941381
# lng                 float64    410      398     1    80.583211  79.694183
# formatted_address    object    411      220     0          NaN        NaN
# rating              float64    355       24    56     4.459437   0.900000
# user_ratings_total  float64    355      316    56  1608.639437  27.000000
# latest_reviews       object    411      411     0          NaN        NaN
#
#                              max
# name                         NaN
# lat                     9.820859
# lng                    81.859583
# formatted_address            NaN
# rating                  5.000000
# user_ratings_total  26736.000000
# latest_reviews               NaN

# %%
print("Shape of places table:",places_df.shape)
print("Shape of users table:",users_df.shape)
# Out:
# Shape of places table: (411, 7)
# Shape of users table: (10000, 5)

# %% [markdown]
# ##### Notes:
#
# * places dataset includes 1 null value in lat & lng and 56 null values in rating & user_ratings_total.
# * Seems like there are some duplicated data also.
# * Need to check whether both prefferd activities and bucket list are taken from a dropdown list or simply typed by each user.
# * If they are selected from a drop down, totally fine.
# * Otherwise we need to identify and merge identical activities across different forms to streamline data.

# %%
# Find duplicated names
duplicated_names = places_df[places_df.duplicated(subset='name', keep=False)]
duplicated_names_sorted = duplicated_names.sort_values('name')

# Display the results
print(f"Number of entries with duplicated names: {len(duplicated_names)}")
print("\nEntries with duplicated names:")
duplicated_names_sorted
# Out:
# Number of entries with duplicated names: 26
#
# Entries with duplicated names:
#                                                   name       lat        lng  \
# 104                    Ambuluwawa Biodiversity Complex  7.161627  80.547197
# 398                    Ambuluwawa Biodiversity Complex  7.161629  80.547189
# 19                               Bundala National Park  6.199086  81.210493
# 405                              Bundala National Park  6.193822  81.187854
# 52            Coral Sanctuary Boat Ticket Issue Center  6.137342  80.099253
# 391           Coral Sanctuary Boat Ticket Issue Center  6.137358  80.099252
# 22        Dambulla Royal Cave Temple and Golden Temple  7.854914  80.650570
# 395       Dambulla Royal Cave Temple and Golden Temple  7.854914  80.650570
# 127                              Elephant Transit Home  6.426689  80.816536
# 400                              Elephant Transit Home  6.426689  80.816536
# 134  Kanneliya National Rain Forest Reserve | ÃƒÂ Ã...  6.257642  80.359621
# 403  Kanneliya National Rain Forest Reserve | ÃƒÂ Ã...  6.257642  80.359621
# 397                                         Kataragama  6.413546  81.332568
# 102                                         Kataragama  6.413546  81.332568
# 84   Limestone Caves|ÃƒÂ Ã‚Â®Ã‚ÂšÃƒÂ Ã‚Â¯Ã‚ÂÃƒÂ Ã‚...  9.820859  80.144544
# 394  Limestone Caves|ÃƒÂ Ã‚Â®Ã‚ÂšÃƒÂ Ã‚Â¯Ã‚ÂÃƒÂ Ã‚...  9.820859  80.144544
# 124                        Madunagala Hot Water Spring  6.253630  80.981711
# 399                        Madunagala Hot Water Spring  6.253630  80.981711
# 70    Makandawa Conservation Center (Makandawa Forest)  6.990920  80.405368
# 392   Makandawa Conservation Center (Makandawa Forest)  6.990920  80.405368
# 6                                      Unawatuna Beach  6.009686  80.248424
# 410                                    Unawatuna Beach  6.009686  80.248424
# 402                                      Ventura Beach  6.423471  79.995320
# 31                                       Ventura Beach  6.423471  79.995320
# 401  Victor Hasselblad Sea Turtle Research And Cons...  6.333735  80.027903
# 130  Victor Hasselblad Sea Turtle Research And Cons...  6.333705  80.027906
#
#                                      formatted_address  rating  \
# 104                                Gampola , Sri Lanka     4.5
# 398                                 Gampola, Sri Lanka     4.7
# 19                                 bundala , Sri Lanka     4.3
# 405                               Weligatta, Sri Lanka     4.3
# 52   ÃƒÂ Ã‚Â·Ã‚Â„ÃƒÂ Ã‚Â·Ã‚Â’ÃƒÂ Ã‚Â¶Ã‚ÂšÃƒÂ Ã‚Â·Ã‚...     4.1
# 391                               Hikkaduwa, Sri Lanka     4.4
# 22                                 Dambulla, Sri Lanka     4.2
# 395                                Dambulla, Sri Lanka     4.3
# 127                               Udawalawa, Sri Lanka     4.6
# 400                               Udawalawa, Sri Lanka     4.6
# 134                                     Sri, Sri Lanka     4.8
# 403                                     Sri, Sri Lanka     4.7
# 397                              Kataragama, Sri Lanka     NaN
# 102                              Kataragama, Sri Lanka     NaN
# 84                           Valvettithurai, Sri Lanka     4.4
# 394                          Valvettithurai, Sri Lanka     4.1
# 124                                          Sri Lanka     4.6
# 399                                          Sri Lanka     4.5
# 70                                Kitulgala, Sri Lanka     4.9
# 392                               Kitulgala, Sri Lanka     4.5
# 6                           Unawatuna Beach, Sri Lanka     4.8
# 410                         Unawatuna Beach, Sri Lanka     4.3
# 402                           Ventura Beach, Sri Lanka     4.4
# 31                            Ventura Beach, Sri Lanka     4.4
# 401                                 Kosgoda, Sri Lanka     4.3
# 130                                 Kosgoda, Sri Lanka     4.3
#
#      user_ratings_total                                     latest_reviews
# 104              3248.0  ['Ambuluwawa Biodiversity Complex is a hidden ...
# 398              3254.0  ['The Ambuluwawa Biodiversity Complex is a hid...
# 19                654.0  ['Bundala National Park is a hidden gem for na...
# 405               561.0  ['Bundala National Park is a hidden gem! I arr...
# 52                209.0  ['I had a fantastic time at the Coral Sanctuar...
# 391               131.0  ['The Coral Sanctuary Boat Ticket Issue Center...
# 22              11598.0  ['The Dambulla Royal Cave Temple is a breathta...
# 395             11690.0  ['Dambulla Royal Cave Temple is a must-visit f...
# 127              1849.0  ['Visiting the Elephant Transit Home was a hea...
# 400              1784.0  ['The Elephant Transit Home is a heartwarming ...
# 134               172.0  ['Kanneliya National Rain Forest Reserve is a ...
# 403               143.0  ['Kanneliya National Rain Forest Reserve is a ...
# 397                 NaN  ['Kataragama was a bit of a letdown for me. Th...
# 102                 NaN  ['Kataragama has a rich cultural significance,...
# 84                196.0  ['The Limestone Caves are a hidden gem in Jaff...
# 394               177.0  ['The Limestone Caves are truly a hidden gem! ...
# 124              1117.0  ['Madunagala Hot Water Spring is a hidden gem!...
# 399              1151.0  ['Madunagala Hot Water Spring is a hidden gem!...
# 70                127.0  ['Makandawa Conservation Center is a true gem!...
# 392               192.0  ['Makandawa Conservation Center is a hidden ge...
# 6                1868.0  ['Unawatuna Beach is a slice of paradise! The ...
# 410              1908.0  ['Unawatuna Beach is a paradise! The soft sand...
# 402               502.0  ['Ventura Beach is a hidden gem! The golden sa...
# 31                516.0  ['Ventura Beach is a hidden gem! The soft, whi...
# 401              1499.0  ['This center is a gem! The commitment to turt...
# 130              1449.0  ['The Victor Hasselblad Sea Turtle Research an...

# %% [markdown]
# ##### Notes:
# * It appears that the places dataset have some non english characters. We need to clean the data in the future steps. Then we can look into a solution for these duplicates. Let's look at it in the later parts.
# * It seems like we need to do some modifications on the `formatted_address` also.

# %%
# Find duplicated emails
duplicated_emails = users_df[users_df.duplicated(subset='Email', keep=False)]

# Sort by email to group duplicates together
duplicated_emails_sorted = duplicated_emails.sort_values('Email')

# Display the results
print(f"Number of entries with duplicated emails: {len(duplicated_emails)}")
print("\nEntries with duplicated emails:")
duplicated_emails_sorted
# Out:
# Number of entries with duplicated emails: 1132
#
# Entries with duplicated emails:
#       User ID            Name                       Email  \
# 1009     1010  Aaron Phillips  aaron.phillips@example.com
# 3779     3780  Aaron Phillips  aaron.phillips@example.com
# 2876     2877    Aaron Walker    aaron.walker@example.com
# 7371     7372    Aaron Walker    aaron.walker@example.com
# 1845     1846    Alicia Jones    alicia.jones@example.com
# ...       ...             ...                         ...
# 6529     6530  William Wilson  william.wilson@example.com
# 4365     4366   Zachary Jones   zachary.jones@example.com
# 5122     5123   Zachary Jones   zachary.jones@example.com
# 3641     3642  Zachary Martin  zachary.martin@example.com
# 5060     5061  Zachary Martin  zachary.martin@example.com
#
#                                    Preferred Activities  \
# 1009  ['butterfly watching', 'sailing', 'elephant ri...
# 3779   ['local crafts', 'hot air ballooning', 'hiking']
# 2876  ['boat safaris', 'yoga retreats', 'museum visi...
# 7371   ['scuba diving', 'yoga retreats', 'photography']
# 1845  ['historic sites', 'animal encounters', 'arts ...
# ...                                                 ...
# 6529  ['sailing lessons', 'sightseeing', 'public art...
# 4365  ['river cruises', 'literary tours', 'public ar...
# 5122  ['beachfront dining', 'landscape photography',...
# 3641       ['caving', 'kayaking', 'temple pilgrimages']
# 5060   ['rock climbing', 'arts and culture', 'safaris']
#
#                      Bucket list destinations Sri Lanka
# 1009  ['Colombo Port City', 'Knuckles', 'Udawalawe',...
# 3779  ["Sri Pada / Adam's Peak", 'Ambalangoda', 'Kan...
# 2876  ['Colombo National Museum', 'Ratnapura Gem Mus...
# 7371  ['Kalpitiya', 'Yala National Park', 'Sinharaja...
# 1845  ['Jaffna Public Library', 'Mihintale', 'Gangar...
# ...                                                 ...
# 6529  ['Pidurangala Rock', 'Negombo', 'Horton Plains...
# 4365  ['Madu River', 'Kandy', 'Bentota River', 'Mart...
# 5122  ['Ella Gap', 'Galle', 'Sigiriya', 'Ahangama', ...
# 3641  ['Belilena Caves', 'Jaya Sri Maha Bodhi', "Sri...
# 5060  ['National Gallery of Art', 'Nelung Arts Centr...
#
# [1132 rows x 5 columns]

# %% [markdown]
# ##### Notes:
# * It appears that the same person has entered their preferences multiple times. We'll retain these entries,assuming they represent different time frames when the individual visits the country on separate occasions.

# %%
unique_activities = users_df['Preferred Activities'].unique()
activities = set()

for activity in unique_activities:
    activity_set = activity.strip("[]'").replace("'", "").split(", ")
    activities.update(activity_set)

sorted_activities = sorted(activities)

print(f"Number of unique activities: {len(sorted_activities)}")
print("Unique activities in alphabetical order:")
for activity in sorted_activities:
    print(activity)
# Out:
# Number of unique activities: 68
# Unique activities in alphabetical order:
# amusement parks
# animal encounters
# archaeological sites
# architecture photography
# architecture tours
# art classes
# arts and culture
# ayurvedic spa treatments
# beach visits
# beachfront dining
# bird watching
# boat safaris
# botanical gardens
# butterfly watching
# camping
# caving
# city tours
# craft workshops
# cultural experiences
# cultural festivals
# cycling
# elephant rides
# fishing
# golfing
# hiking
# historic sites
# historic walks
# historical monuments
# history tours
# horse shows
# horseback riding
# hot air ballooning
# hot springs
# kayaking
# landscape photography
# literary tours
# local crafts
# mountain biking
# museum visits
# outdoor adventures
# paddleboarding
# photography
# planetarium visits
# public art installations
# river cruises
# rock climbing
# safaris
# sailing
# sailing lessons
# scuba diving
# sea cruises
# sightseeing
# snorkeling
# spiritual retreats
# surfing
# tea tasting
# temple pilgrimages
# theater
# themed parks
# traditional ceremonies
# turtle watching
# village homestays
# water parks
# waterfalls
# whale watching
# wildlife viewing
# yoga retreats
# zip-lining

# %% [markdown]
# ##### Notes:
# * This analysis shows that the activities are from a dropdown selection or a selection of activities that the user can choose from. All good!

# %%
unique_bucket_places = users_df['Bucket list destinations Sri Lanka'].unique()
bucket_places = set()

for bucket_place in unique_bucket_places:
    bucket_place_set = bucket_place.strip("[]'").replace("'", "").split(", ")
    bucket_places.update(bucket_place_set)

# Remove unwanted signs and whitespace at the beginning and end of place names
cleaned_bucket_places = {place.strip('"').strip() for place in bucket_places}

sorted_bucket_places = sorted(cleaned_bucket_places)

print(f"Number of unique bucket list destinations: {len(sorted_bucket_places)}")
print("Unique bucket list destinations in alphabetical order:")
for bucket_place in sorted_bucket_places:
    print(bucket_place)
# Out:
# Number of unique bucket list destinations: 159
# Unique bucket list destinations in alphabetical order:
# Ahangama
# Ahungalla
# Ambalangoda
# Ambalangoda Mask Workshop
# Ambuluwawa Tower
# Anawilundawa Wetlands
# Anuradapura
# Anuradhapura
# Arankelle Forest Monastery
# Arugam Bay Beach
# Bakers Falls
# Bambarakanda Falls
# Bambarakiri Ella
# Batadombalena Craft Centre
# Batatotalena (Batadombalena) Cave
# Belihuloya
# Belilena Caves
# Bentota
# Bentota Beach
# Bentota River
# Bolgoda Lake
# Bomburu Ella Waterfall
# Bopath Falls
# Bundala National Park
# Colombo
# Colombo City Tour
# Colombo National Museum
# Colombo Port City
# Dambulla
# Dambulla Royal Cave Temple and Golden Temple
# Devon Falls
# Diyaluma Falls
# Dry Zone Botanic Gardens
# Dunhinda Waterfall
# Dutch Museum
# Elephant Transit Home
# Ella
# Ella Gap
# Ella Rock
# Excel World
# Folk Museum
# Galle
# Galle City Tour
# Galle Dutch Fort
# Galle Fort
# Galle Lighthouse
# Gangaramaya Temple
# Hakgala Botanical Garden
# Hambantota
# Haputale
# Hatton
# Hikkaduwa
# Hikkaduwa Beach
# Hikkaduwa Coral Sanctuary
# Hiriketiya
# Hiriketiya Beach
# Horton Plains
# Horton Plains National Park
# Jaffna Public Library
# Jaya Sri Maha Bodhi
# Jungle Beach
# Jungle beach
# Kalpitiya
# Kalpitiya Lagoon
# Kandalama
# Kandy
# Kandy City Centre
# Kandy Lake
# Kandy National Museum
# Kandy Temple
# Kanneliya National Rain Forest Reserve
# Kanniya Hot Springs
# Kithulgala
# Kitugala Forest
# Kitulgala
# Knuckles
# Koggala Beach
# Kosgoda Turtle Hatchery
# Kumana National Park
# Laxapana Falls
# Leisure World
# Lionel Wendt Art Centre
# Madu River
# Madunagala Hot Water Spring
# Maha Oya Hot Water Springs
# Mahalenama Cave
# Mahapelessa Hot Springs
# Marakolliya Beach
# Maritime Museum
# Martin Wickramasinghe Folk Museum
# Meemure
# Mihintale
# Minneriya National Park
# Mirissa Beach
# Museum of Modern and Contemporary Art
# Nallur Kandaswamy Devasthanam
# Nallur Kandaswamy Kovil
# National Gallery of Art
# National Museum Galle
# Negambo
# Negombo
# Negombo Lagoon
# Nelum Pokuna Theatre
# Nelung Arts Centre
# Nilaveli Beach
# Nine Arches Bridge
# Nuwara Eliya
# Nuwara Eliya Golf Club
# Passikuda Beach
# Pearl Bay
# Peradeniya
# Perl Bay
# Pidurangala Rock
# Pigeon Island
# Pinnawala
# Pinnawala Elephant Orphanage
# Polonaruwa
# Polonnaruwa
# Polonnaruwa Ancient City
# Ramboda Falls
# Ratnapura Gem Museum
# Ravan Ella Waterfall
# Rekawa Beach
# Ritigala
# Riverstone Gap
# Royal Botanical Gardens
# Royal Colombo Golf Club
# Ruhunu Maha Kataragama Dewalaya
# Seetha Eliya
# Seethawaka Wet Zone Botanical Gardens
# Sigiriya
# Sinharaja Forest Reserve
# Sri Dalada Maligawa
# Sri Lanka Planetarium
# Sri Pada / Adams Peak
# St Clairs Falls
# Surathali Ella
# Tangalle
# Tangalle Beach
# Trincomalee
# Trincomalee Harbour
# Udawalawe
# Udawalawe National Park
# Unawatuna
# Unawatuna Beach
# Unawatuna Lagoon
# Uppuveli Beach
# Vaddha Village Camping
# Velgam Vehera Buddhist Temple
# Victoria Golf Club
# Viharamahadevi Park
# Wasgamuwa National Park
# Water World Lanka
# Wavulpone Cave
# Weligama Beach
# Weligama Beach (surf and stay)
# Wilpattu National Park
# Yala National Park
# Yapahuwa Rock Fortress

# %% [markdown]
# ##### Notes:
# * This analysis shows that the bucket list places are manually entered by the user.
# * We need to identify and merge identical places across different forms to streamline data.

# %%
def find_similar_places(places, threshold=90):
    similar_places = {}
    for place in places:
        matches = process.extract(place, places, limit=len(places), scorer=fuzz.token_sort_ratio)
        similar = [match for match in matches if match[1] >= threshold and match[0] != place]
        if similar:
            similar_places[place] = similar
    return similar_places

# Use the bucket_places set directly
unique_places = list(bucket_places)  

# Find similar places with similarity > 90%
similar_places = find_similar_places(unique_places, threshold=90)

print("Places with similarity")
for place, matches in similar_places.items():
    print(f"\nSimilar to '{place}':")
    for match in matches:
        print(f"  - '{match[0]}' (similarity: {match[1]}%)")

# Print total count of similar place groups
print(f"\nTotal number of place groups with high similarity: {len(similar_places)}")
# Out:
# Places with similarity
#
# Similar to 'Pearl Bay':
#   - 'Perl Bay' (similarity: 94%)
#
# Similar to 'Perl Bay':
#   - 'Pearl Bay' (similarity: 94%)
#
# Similar to 'Jungle Beach':
#   - 'Jungle beach' (similarity: 100%)
#
# Similar to 'Anuradhapura':
#   - 'Anuradapura' (similarity: 96%)
#
# Similar to 'Kitulgala':
#   - 'Kithulgala' (similarity: 95%)
#
# Similar to 'Jungle beach':
#   - 'Jungle Beach' (similarity: 100%)
#
# Similar to 'Kithulgala':
#   - 'Kitulgala' (similarity: 95%)
#
# Similar to 'Polonnaruwa':
#   - 'Polonaruwa' (similarity: 95%)
#
# Similar to 'Anuradapura':
#   - 'Anuradhapura' (similarity: 96%)
#
# Similar to 'Polonaruwa':
#   - 'Polonnaruwa' (similarity: 95%)
#
# Total number of place groups with high similarity: 10

# %% [markdown]
# ##### Notes:
# * We'll try to solve this problem in the later parts.

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# #### Let's remove non-English characters in places dataset

# %%
import re

def clean_text(text):
    # Remove all characters except alphabets, numbers, and punctuation
    #cleaned = re.sub(r'[^\w\s.,!?;:()-]', '', str(text))
    cleaned = re.sub(r'[^A-Za-z\s.,]', '', str(text))
    # Normalize spaces
    cleaned = re.sub(r'\s+', ' ', cleaned)
    return cleaned.strip()

# Apply the cleaning function to the 'name', 'latest_reviews' and 'formatted_address' columns in the places dataframe
places_df['name'] = places_df['name'].apply(clean_text)
places_df['latest_reviews'] = places_df['latest_reviews'].apply(clean_text)
places_df['formatted_address'] = places_df['formatted_address'].apply(clean_text)

# %% [markdown]
# #### Let's manipulate the duplicates in places dataset

# %%
# Find duplicated names
duplicated_names = places_df[places_df.duplicated(subset='name', keep=False)]
duplicated_names_sorted = duplicated_names.sort_values('name')

# Display the results
print(f"Number of entries with duplicated names: {len(duplicated_names)}")

# Group duplicates and aggregate
def aggregate_duplicates(group):
    first_record = group.iloc[0]
    second_record = group.iloc[1] if len(group) > 1 else None
    
    # Take lat, lng, formatted_address from the first record, if present, otherwise from the second
    lat = first_record['lat'] if pd.notna(first_record['lat']) else (second_record['lat'] if second_record is not None else None)
    lng = first_record['lng'] if pd.notna(first_record['lng']) else (second_record['lng'] if second_record is not None else None)
    formatted_address = first_record['formatted_address'] if pd.notna(first_record['formatted_address']) else (second_record['formatted_address'] if second_record is not None else None)
    
    # Calculate weighted average rating
    total_ratings = group['user_ratings_total'].sum()
    if total_ratings > 0:
        weighted_rating = (group['rating'] * group['user_ratings_total']).sum() / total_ratings
    else:
        weighted_rating = group['rating'].mean()
    
    # Combine latest_reviews
    combined_reviews = ' '.join(group['latest_reviews'].dropna())
    
    return pd.Series({
        'lat': lat,
        'lng': lng,
        'formatted_address': formatted_address,
        'rating': weighted_rating,
        'user_ratings_total': total_ratings,
        'latest_reviews': combined_reviews
    })

# Apply the aggregation
places_deduplicated = places_df.groupby('name').apply(aggregate_duplicates).reset_index()

# Print the results
print(f"Number of entries before deduplication: {len(places_df)}")
print(f"Number of entries after deduplication: {len(places_deduplicated)}")

# Update the original places dataframe
places_df = places_deduplicated
# Out:
# Number of entries with duplicated names: 28
# Number of entries before deduplication: 411
# Number of entries after deduplication: 397
# C:\Users\Akindu Himan\AppData\Local\Temp\ipykernel_12508\2662675699.py:38: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   places_deduplicated = places_df.groupby('name').apply(aggregate_duplicates).reset_index()

# %%
# Removing 'Anuradhapura' and 'Colombo' because we have 'Anuradhapura New Town' and 'Colombo City Tour'
places_df = places_df[~places_df['name'].isin(['Anuradhapura', 'Colombo'])]
places_df = places_df.reset_index(drop=True)

# %% [markdown]
# #### Let's fix the `formatted_address` section in places dataset

# %%
# Remove 'Sri Lanka' from the formatted_address column
places_df['formatted_address'] = places_df['formatted_address'].str.replace(', Sri Lanka', '', regex=False)

# %%
places_df[places_df['formatted_address'] == ""]
# Out:
#                                          name       lat        lng  \
# 56   Coral Sanctuary Boat Ticket Issue Center  6.137342  80.099253
# 93                     Fort Entrance Old Gate  6.028114  80.218447
# 171                    Kudawa Beach Kalpitiya  8.227305  79.728156
# 203                          Mayan Water Park  7.068894  79.902236
#
#     formatted_address    rating  user_ratings_total  \
# 56                     4.215588               340.0
# 93                     4.800000               231.0
# 171                    4.300000               329.0
# 203                    3.700000               562.0
#
#                                         latest_reviews
# 56   I had a fantastic time at the Coral Sanctuary ...
# 93   The Fort Entrance, or Old Gate, is a captivati...
# 171  Kudawa Beach Kalpitiya is a hidden gem The sof...
# 203  Mayan Water Park was a decent outing for my fa...

# %%
places_df[places_df['formatted_address'] == "Sri"]
# Out:
#                                        name       lat        lng  \
# 150  Kanneliya National Rain Forest Reserve  6.257642  80.359621
#
#     formatted_address    rating  user_ratings_total  \
# 150               Sri  4.754603               315.0
#
#                                         latest_reviews
# 150  Kanneliya National Rain Forest Reserve is a hi...

# %%
places_df[places_df['formatted_address'] == "Sri Lanka"]
# Out:
#                             name       lat        lng formatted_address  \
# 5       Alankuda Casuarina Beach  8.048135  79.709916         Sri Lanka
# 26              Bambarakiri Ella  7.495246  80.699001         Sri Lanka
# 29              Bathalagoda Tank  7.531868  80.450986         Sri Lanka
# 82               Dutch Bay Beach  8.573372  81.239508         Sri Lanka
# 121  Horton Plains National Park  6.809446  80.802333         Sri Lanka
# 153            Kattukkarai Kulam  8.862747  80.015727         Sri Lanka
# 167               Kokkilai Beach  9.064594  80.918706         Sri Lanka
# 168       Korathota Royal Temple  6.915038  80.002135         Sri Lanka
# 177                Leisure World       NaN        NaN         Sri Lanka
# 187  Madunagala Hot Water Spring  6.253630  80.981711         Sri Lanka
# 197            Manelwatta Temple  6.944921  79.951361         Sri Lanka
# 207               Midigama Right  5.964815  80.383642         Sri Lanka
# 210      Minneriya National Park  8.015644  80.844670         Sri Lanka
# 282           Rajanawa Waterfall  6.654697  80.441370         Sri Lanka
# 319     Sinharaja Forest Reserve  6.406991  80.460027         Sri Lanka
# 346              Thalawila Beach  8.111427  79.701862         Sri Lanka
# 362      Udawalawe National Park  6.474629  80.876319         Sri Lanka
# 372      Vankalai Bird Sanctuary  8.919994  79.932892         Sri Lanka
# 386       Wilpattu National Park  8.458182  80.051831         Sri Lanka
# 390           Yala National Park  6.463961  81.471885         Sri Lanka
#
#       rating  user_ratings_total  \
# 5    4.30000                99.0
# 26   4.40000              2004.0
# 29   4.70000                60.0
# 82   4.30000               396.0
# 121  4.70000              8564.0
# 153  4.20000               121.0
# 167  3.90000               140.0
# 168  4.80000              1226.0
# 177      NaN                 0.0
# 187  4.54925              2268.0
# 197  4.80000              1673.0
# 207  4.80000               217.0
# 210  4.60000              1293.0
# 282  4.40000               182.0
# 319  4.30000              2062.0
# 346  4.30000               134.0
# 362  4.30000              6156.0
# 372  3.70000               155.0
# 386  4.70000              2708.0
# 390  4.10000              2810.0
#
#                                         latest_reviews
# 5    Alankuda Casuarina Beach is a hidden gem The p...
# 26   Bambarakiri Ella is a beautiful, serene spot t...
# 29   Bathalagoda Tank is such a hidden gem I visite...
# 82   Dutch Bay Beach is an absolute gem The cleanli...
# 121  Horton Plains National Park was an incredible ...
# 153  Kattukkarai Kulam is a hidden gem in the North...
# 167  Kokkilai Beach is a hidden gem The tranquil at...
# 168  Korathota Royal Temple is a hidden gem The cli...
# 177  Leisure World has potential, but my experience...
# 187  Madunagala Hot Water Spring is a hidden gem Th...
# 197  Visiting Manelwatta Temple was a serene experi...
# 207  Midigama Right is a hidden gem The water is cr...
# 210  Minneriya National Park is a mustvisit for wil...
# 282  Rajanawa Waterfall is a hidden gem The sound o...
# 319  Exploring Sinharaja Forest Reserve was a magic...
# 346  Thalawila Beach is a hidden gem The soft sand ...
# 362  Udawalawe National Park was absolutely breatht...
# 372  The Vankalai Bird Sanctuary is a hidden gem in...
# 386  Wilpattu National Park is a fantastic destinat...
# 390  Yala National Park is a true gem for wildlife ...

# %%
places_df.loc[places_df['name'] == 'Coral Sanctuary Boat Ticket Issue Center', 'formatted_address'] = 'Hikkaduwa'
places_df.loc[places_df['name'] == 'Fort Entrance Old Gate', 'formatted_address'] = 'Galle'
places_df.loc[places_df['name'] == 'Kudawa Beach Kalpitiya', 'formatted_address'] = 'Kalpitiya'
places_df.loc[places_df['name'] == 'Mayan Water Park', 'formatted_address'] = 'Negombo'
places_df.loc[places_df['name'] == 'Kanneliya National Rain Forest Reserve', 'formatted_address'] = 'Kanneliya'
places_df.loc[places_df['name'] == 'Alankuda Casuarina Beach', 'formatted_address'] = 'Kalpitiya'
places_df.loc[places_df['name'] == 'Bambarakiri Ella', 'formatted_address'] = 'Kandy'
places_df.loc[places_df['name'] == 'Bathalagoda Tank', 'formatted_address'] = 'Kurunegala'
places_df.loc[places_df['name'] == 'Dutch Bay Beach', 'formatted_address'] = 'Trincomalee'
places_df.loc[places_df['name'] == 'Horton Plains National Park', 'formatted_address'] = 'Nuwara Eliya'
places_df.loc[places_df['name'] == 'Kattukkarai Kulam', 'formatted_address'] = 'Vavuniya'
places_df.loc[places_df['name'] == 'Kokkilai Beach', 'formatted_address'] = 'Kokkilai'
places_df.loc[places_df['name'] == 'Korathota Royal Temple', 'formatted_address'] = 'Korathota'
places_df.loc[places_df['name'] == 'Leisure World', 'formatted_address'] = 'Hanwella'
places_df.loc[places_df['name'] == 'Madunagala Hot Water Spring', 'formatted_address'] = 'Hambantota'
places_df.loc[places_df['name'] == 'Manelwatta Temple', 'formatted_address'] = 'Gampaha'
places_df.loc[places_df['name'] == 'Midigama Right', 'formatted_address'] = 'Midigama'
places_df.loc[places_df['name'] == 'Minneriya National Park', 'formatted_address'] = 'Habarana'
places_df.loc[places_df['name'] == 'Rajanawa Waterfall', 'formatted_address'] = 'Ratnapura'
places_df.loc[places_df['name'] == 'Sinharaja Rain Forest', 'formatted_address'] = 'Sinharaja Forest Reserve'
places_df.loc[places_df['name'] == 'Thalawila Beach', 'formatted_address'] = 'Kalpitiya'
places_df.loc[places_df['name'] == 'Udawalawe National Park', 'formatted_address'] = 'Udawalawe'
places_df.loc[places_df['name'] == 'Vankalai Bird Sanctuary', 'formatted_address'] = 'Mannar'
places_df.loc[places_df['name'] == 'Wilpattu National Park', 'formatted_address'] = 'Puttalam'	
places_df.loc[places_df['name'] == 'Yala National Park', 'formatted_address'] = 'Hambantota'
places_df.loc[places_df['name'] == 'Aanda Ella Fall', 'formatted_address'] = 'Ratnapura'

# %% [markdown]
# #### Handeling missing values

# %%
# Check for null values in lat or lng columns
null_lat_lng = places_df[places_df['lat'].isnull() | places_df['lng'].isnull()]
null_lat_lng
# Out:
#               name  lat  lng formatted_address  rating  user_ratings_total  \
# 177  Leisure World  NaN  NaN          Hanwella     NaN                 0.0
#
#                                         latest_reviews
# 177  Leisure World has potential, but my experience...

# %%
# Manually add lat and lng
places_df.loc[places_df['name'] == 'Leisure World', 'lat'] = 6.9167
places_df.loc[places_df['name'] == 'Leisure World', 'lng'] = 80.0667

# %%
# Check for null values in the rating column
null_ratings = places_df[places_df['rating'].isnull()]
num_null_ratings = null_ratings.shape[0]
print(f"\nNumber of places with null ratings: {num_null_ratings}")
null_ratings
# Out:
# Number of places with null ratings: 53
#                             name       lat        lng      formatted_address  \
# 2                       Ahangama  5.973975  80.362159               Ahangama
# 3                      Ahungalla  6.313278  80.040918              Ahungalla
# 9                    Ambalangoda  6.244152  80.059080            Ambalangoda
# 12          Anawilundawa Wetland  7.709595  79.821270   Anawilundawa Wetland
# 34                    Belihuloya  6.718399  80.774091             Belihuloya
# 62                      Dambulla  7.874217  80.651129               Dambulla
# 76               Diyagala Escape  6.706992  80.439074              Ratnapura
# 83                  Dutch Cannon  7.711577  81.702434             Batticaloa
# 98                         Galle  6.032895  80.216791                  Galle
# 108                     Haputale  6.765414  80.952565               Haputale
# 114           Heyna camping site  6.207340  81.272014              Weligatta
# 115  Hidden Water fall Tiny Ella  7.278051  80.630203                  Kandy
# 117                    Hikkaduwa  6.139468  80.106286              Hikkaduwa
# 136               Kadawatha Wewa  8.662155  80.541028          Puhudivula Rd
# 139                    Kalpitiya  8.229528  79.759614              Kalpitiya
# 143                    Kandalama  7.888498  80.710353              Kandalama
# 144                        Kandy  7.290572  80.633726                  Kandy
# 152                   Kataragama  6.413546  81.332568             Kataragama
# 155            Katukeliyawa Wewa  8.681588  80.570894             Puhudivula
# 161      Kiriwalketiya waterfall  6.637441  80.455778            Nivithigala
# 162                    Kitulgala  6.989784  80.427088              Kitulgala
# 165                      Koggala  6.000704  80.335236                Koggala
# 170         Kuda Meegaskada Wewa  8.667744  80.571630             Puhudivula
# 174             Lake side cabana  8.574241  81.220538           Trincomalee
# 177                Leisure World  6.916700  80.066700               Hanwella
# 188         Maha Meegaskada Wewa  8.672284  80.574627             Puhudivula
# 191           Mahakarambewa Wewa  8.034722  79.942222     Mahakarambewa Wewa
# 199                  Marakolliya  6.061372  80.818401            Marakolliya
# 204                      Meemure  7.432645  80.846082                Meemure
# 205             Mekichchawa Wewa  8.661152  80.542828          Puhudivula Rd
# 212                      Mirissa  5.948262  80.471587                Mirissa
# 223       Narangala N view point  7.025305  80.993622              Narangala
# 230                      Negombo  7.205521  79.851256                Negombo
# 241           Nine Arches Bridge  6.876815  81.060846                   Ella
# 244                 Nuwara Eliya  6.949717  80.789107           Nuwara Eliya
# 247       Nuwara Wewa View Point  8.336791  80.416116           Anuradhapura
# 254              Panakala Lagoon  6.732608  81.793739               Lahugala
# 271                    Pinnawala  7.301495  80.386742             Rambukkana
# 273        Pitawala Nature Trail  7.548983  80.751473  Pitawala Nature Trail
# 275                  Polonnaruwa  7.940338  81.018798            Polonnaruwa
# 279            Port City Colombo  6.937804  79.836843      Port City Colombo
# 293        Ridiyagama waterfront  6.209217  80.968159          Siyambalagoda
# 294          Rillamba Surf Point  6.032895  80.216791                  Galle
# 315                 Seetha Eliya  6.933208  80.810268           Seetha Eliya
# 342                     Tangalle  6.024338  80.794073               Tangalle
# 348            Thandiyadi Lagoon  7.051927  81.845720          Vinayagapuram
# 356                  Trincomalee  8.587364  81.215212            Trincomalee
# 361                    Udawalawa  6.418483  80.823938              Udawalawa
# 366                    Unawatuna  6.017447  80.248860              Unawatuna
# 369                     Uppuveli  8.601562  81.219524            Trincomalee
# 380                Watawala Ella  6.628570  80.360297               Niriella
# 382           Wedikkarayage Wewa  8.669136  80.540823          Puhudivula Rd
# 394                    rumassala  6.032895  80.216791                  Galle
#
#      rating  user_ratings_total  \
# 2       NaN                 0.0
# 3       NaN                 0.0
# 9       NaN                 0.0
# 12      NaN                 0.0
# 34      NaN                 0.0
# 62      NaN                 0.0
# 76      NaN                 0.0
# 83      NaN                 0.0
# 98      NaN                 0.0
# 108     NaN                 0.0
# 114     NaN                 0.0
# 115     NaN                 0.0
# 117     NaN                 0.0
# 136     NaN                 0.0
# 139     NaN                 0.0
# 143     NaN                 0.0
# 144     NaN                 0.0
# 152     NaN                 0.0
# 155     NaN                 0.0
# 161     NaN                 0.0
# 162     NaN                 0.0
# 165     NaN                 0.0
# 170     NaN                 0.0
# 174     NaN                 0.0
# 177     NaN                 0.0
# 188     NaN                 0.0
# 191     NaN                 0.0
# 199     NaN                 0.0
# 204     NaN                 0.0
# 205     NaN                 0.0
# 212     NaN                 0.0
# 223     NaN                 0.0
# 230     NaN                 0.0
# 241     NaN                 0.0
# 244     NaN                 0.0
# 247     NaN                 0.0
# 254     NaN                 0.0
# 271     NaN                 0.0
# 273     NaN                 0.0
# 275     NaN                 0.0
# 279     NaN                 0.0
# 293     NaN                 0.0
# 294     NaN                 0.0
# 315     NaN                 0.0
# 342     NaN                 0.0
# 348     NaN                 0.0
# 356     NaN                 0.0
# 361     NaN                 0.0
# 366     NaN                 0.0
# 369     NaN                 0.0
# 380     NaN                 0.0
# 382     NaN                 0.0
# 394     NaN                 0.0
#
#                                         latest_reviews
# 2    Ahangama was a bit disappointing for me as a s...
# 3    Ahungalla seemed promising, but I found it a b...
# 9    Ambalangoda had potential, but it fell short o...
# 12   I visited Anawilundawa Wetland expecting a vib...
# 34   Belihuloya was a bit disappointing for me. The...
# 62   Dambulla was a bit of a letdown for me. The ho...
# 76   Diyagala Escape was a bit disappointing overal...
# 83   Visiting the Dutch Cannon was a bit disappoint...
# 98   Galle has some charm, but honestly, I expected...
# 108  Haputale is a beautiful location with stunning...
# 114  The Heyna camping site was a bit of a letdown....
# 115  The hike to Hidden Waterfall Tiny Ella was mor...
# 117  Hikkaduwa was quite disappointing for a beach ...
# 136  Kadawatha Wewa was a bit of a letdown. The sce...
# 139  Kalpitiya has beautiful scenery, but I was dis...
# 143  Kandalama was a bit of a letdown for me. The h...
# 144  Kandy has its moments, but overall, I found it...
# 152  Kataragama has a rich cultural significance, b...
# 155  Katukeliyawa Wewa was a bit disappointing. The...
# 161  The Kiriwalketiya waterfall was a bit of a let...
# 162  Kitulgala has potential, but my experience was...
# 165  Koggala beach has stunning scenery, but I was ...
# 170  Kuda Meegaskada Wewa was a bit of a letdown. T...
# 174  The Lake Side Cabana has a stunning view, but ...
# 177  Leisure World has potential, but my experience...
# 188  Maha Meegaskada Wewa was a bit of a disappoint...
# 191  Mahakarambewa Wewa was a bit of a letdown. The...
# 199  Marakolliya has stunning scenery, but my exper...
# 204  Meemure is a beautiful spot, but I was a bit d...
# 205  The Mekichchawa Wewa was a bit of a letdown fo...
# 212  I recently went on a sea cruise in Mirissa, an...
# 223  The hike to Narangala viewpoint was more chall...
# 230  Negombo was a bit of a letdown for me. I expec...
# 241  The Nine Arches Bridge is visually stunning, b...
# 244  Nuwara Eliya is a bit overrated for its charm....
# 247  The view from Nuwara Wewa View Point was quite...
# 254  Panakala Lagoon was a bit of a letdown. The sc...
# 271  Pinnawala was a bit of a letdown. While the el...
# 273  The Pitawala Nature Trail was a bit underwhelm...
# 275  Polonnaruwa felt like a missed opportunity. Wh...
# 279  Port City Colombo has a lot of potential, but ...
# 293  The Ridiyagama waterfront was a bit underwhelm...
# 294  Rillamba Surf Point was a bit disappointing. T...
# 315  Seetha Eliya has some beautiful scenery, but m...
# 342  Tangalle was a bit of a letdown for me. The be...
# 348  Thandiyadi Lagoon was a bit of a letdown for m...
# 356  I had high expectations for Trincomalee, but I...
# 361  Udawalawa was a bit of a letdown. The elephant...
# 366  Unawatuna has beautiful beaches, but I found i...
# 369  Uppuveli has a stunning shoreline, but I found...
# 380  Watawala Ella has stunning views, but I found ...
# 382  Wedikkarayage Wewa was a bit of a letdown for ...
# 394  Rumassala was a bit of a letdown. The views we...

# %% [markdown]
# ##### Notes:
# * As these places are more like main cities there isn't ratings foe these places in google maps. We need to find a other way to fill them.

# %%
sorted_bucket_places
# Out:
# ['Ahangama',
#  'Ahungalla',
#  'Ambalangoda',
#  'Ambalangoda Mask Workshop',
#  'Ambuluwawa Tower',
#  'Anawilundawa Wetlands',
#  'Anuradapura',
#  'Anuradhapura',
#  'Arankelle Forest Monastery',
#  'Arugam Bay Beach',
#  'Bakers Falls',
#  'Bambarakanda Falls',
#  'Bambarakiri Ella',
#  'Batadombalena Craft Centre',
#  'Batatotalena (Batadombalena) Cave',
#  'Belihuloya',
#  'Belilena Caves',
#  'Bentota',
#  'Bentota Beach',
#  'Bentota River',
#  'Bolgoda Lake',
#  'Bomburu Ella Waterfall',
#  'Bopath Falls',
#  'Bundala National Park',
#  'Colombo',
#  'Colombo City Tour',
#  'Colombo National Museum',
#  'Colombo Port City',
#  'Dambulla',
#  'Dambulla Royal Cave Temple and Golden Temple',
#  'Devon Falls',
#  'Diyaluma Falls',
#  'Dry Zone Botanic Gardens',
#  'Dunhinda Waterfall',
#  'Dutch Museum',
#  'Elephant Transit Home',
#  'Ella',
#  'Ella Gap',
#  'Ella Rock',
#  'Excel World',
#  'Folk Museum',
#  'Galle',
#  'Galle City Tour',
#  'Galle Dutch Fort',
#  'Galle Fort',
#  'Galle Lighthouse',
#  'Gangaramaya Temple',
#  'Hakgala Botanical Garden',
#  'Hambantota',
#  'Haputale',
#  'Hatton',
#  'Hikkaduwa',
#  'Hikkaduwa Beach',
#  'Hikkaduwa Coral Sanctuary',
#  'Hiriketiya',
#  'Hiriketiya Beach',
#  'Horton Plains',
#  'Horton Plains National Park',
#  'Jaffna Public Library',
#  'Jaya Sri Maha Bodhi',
#  'Jungle Beach',
#  'Jungle beach',
#  'Kalpitiya',
#  'Kalpitiya Lagoon',
#  'Kandalama',
#  'Kandy',
#  'Kandy City Centre',
#  'Kandy Lake',
#  'Kandy National Museum',
#  'Kandy Temple',
#  'Kanneliya National Rain Forest Reserve',
#  'Kanniya Hot Springs',
#  'Kithulgala',
#  'Kitugala Forest',
#  'Kitulgala',
#  'Knuckles',
#  'Koggala Beach',
#  'Kosgoda Turtle Hatchery',
#  'Kumana National Park',
#  'Laxapana Falls',
#  'Leisure World',
#  'Lionel Wendt Art Centre',
#  'Madu River',
#  'Madunagala Hot Water Spring',
#  'Maha Oya Hot Water Springs',
#  'Mahalenama Cave',
#  'Mahapelessa Hot Springs',
#  'Marakolliya Beach',
#  'Maritime Museum',
#  'Martin Wickramasinghe Folk Museum',
#  'Meemure',
#  'Mihintale',
#  'Minneriya National Park',
#  'Mirissa Beach',
#  'Museum of Modern and Contemporary Art',
#  'Nallur Kandaswamy Devasthanam',
#  'Nallur Kandaswamy Kovil',
#  'National Gallery of Art',
#  'National Museum Galle',
#  'Negambo',
#  'Negombo',
#  'Negombo Lagoon',
#  'Nelum Pokuna Theatre',
#  'Nelung Arts Centre',
#  'Nilaveli Beach',
#  'Nine Arches Bridge',
#  'Nuwara Eliya',
#  'Nuwara Eliya Golf Club',
#  'Passikuda Beach',
#  'Pearl Bay',
#  'Peradeniya',
#  'Perl Bay',
#  'Pidurangala Rock',
#  'Pigeon Island',
#  'Pinnawala',
#  'Pinnawala Elephant Orphanage',
#  'Polonaruwa',
#  'Polonnaruwa',
#  'Polonnaruwa Ancient City',
#  'Ramboda Falls',
#  'Ratnapura Gem Museum',
#  'Ravan Ella Waterfall',
#  'Rekawa Beach',
#  'Ritigala',
#  'Riverstone Gap',
#  'Royal Botanical Gardens',
#  'Royal Colombo Golf Club',
#  'Ruhunu Maha Kataragama Dewalaya',
#  'Seetha Eliya',
#  'Seethawaka Wet Zone Botanical Gardens',
#  'Sigiriya',
#  'Sinharaja Forest Reserve',
#  'Sri Dalada Maligawa',
#  'Sri Lanka Planetarium',
#  'Sri Pada / Adams Peak',
#  'St Clairs Falls',
#  'Surathali Ella',
#  'Tangalle',
#  'Tangalle Beach',
#  'Trincomalee',
#  'Trincomalee Harbour',
#  'Udawalawe',
#  'Udawalawe National Park',
#  'Unawatuna',
#  'Unawatuna Beach',
#  'Unawatuna Lagoon',
#  'Uppuveli Beach',
#  'Vaddha Village Camping',
#  'Velgam Vehera Buddhist Temple',
#  'Victoria Golf Club',
#  'Viharamahadevi Park',
#  'Wasgamuwa National Park',
#  'Water World Lanka',
#  'Wavulpone Cave',
#  'Weligama Beach',
#  'Weligama Beach (surf and stay)',
#  'Wilpattu National Park',
#  'Yala National Park',
#  'Yapahuwa Rock Fortress']

# %%
places_df['name']
# Out:
# 0             Aanda Ella Fall
# 1          Aberdeen Waterfall
# 2                    Ahangama
# 3                   Ahungalla
# 4            Alahana Pirivena
#                 ...
# 390        Yala National Park
# 391    Yapahuwa Rock Fortress
# 392        jungle muru safari
# 393        riapla Mask Museum
# 394                 rumassala
# Name: name, Length: 395, dtype: object

# %% [markdown]
# #### Identifying places on both datasets

# %%
# Convert places['name'] to a set for efficient comparison
places_set = set(places_df['name'].str.lower().str.strip())

# Convert sorted_bucket_places to a set of lowercase strings for comparison
bucket_places_set = set(place.lower().strip() for place in sorted_bucket_places)

# Find common places
common_places = places_set.intersection(bucket_places_set)

# Sort the common places for easier reading
common_places_sorted = sorted(common_places)

# Print the results
print(f"Number of places in both datasets: {len(common_places)}")
print("\nPlaces that appear in both 'places' dataset and bucket list:")
for place in common_places_sorted:
    print(f"- {place}")

# Optional: Find places only in 'places' dataset
places_only = places_set - bucket_places_set
print(f"\nNumber of places only in 'places' dataset: {len(places_only)}")

# Optional: Find places only in bucket list
bucket_only = bucket_places_set - places_set
print(f"Number of places only in bucket list: {len(bucket_only)}")
# Out:
# Number of places in both datasets: 104
#
# Places that appear in both 'places' dataset and bucket list:
# - ahangama
# - ahungalla
# - ambalangoda
# - arugam bay beach
# - bakers falls
# - bambarakanda falls
# - bambarakiri ella
# - belihuloya
# - bolgoda lake
# - bomburu ella waterfall
# - bopath falls
# - bundala national park
# - colombo city tour
# - colombo national museum
# - dambulla
# - dambulla royal cave temple and golden temple
# - devon falls
# - diyaluma falls
# - dunhinda waterfall
# - dutch museum
# - elephant transit home
# - galle
# - galle dutch fort
# - galle lighthouse
# - gangaramaya temple
# - hakgala botanical garden
# - haputale
# - hikkaduwa
# - hikkaduwa beach
# - hiriketiya beach
# - horton plains national park
# - jaffna public library
# - jaya sri maha bodhi
# - jungle beach
# - kalpitiya
# - kalpitiya lagoon
# - kandalama
# - kandy
# - kandy city centre
# - kandy lake
# - kandy national museum
# - kanneliya national rain forest reserve
# - kitulgala
# - knuckles
# - koggala beach
# - kumana national park
# - laxapana falls
# - leisure world
# - lionel wendt art centre
# - madunagala hot water spring
# - maha oya hot water springs
# - marakolliya beach
# - maritime museum
# - martin wickramasinghe folk museum
# - meemure
# - mihintale
# - minneriya national park
# - mirissa beach
# - nallur kandaswamy devasthanam
# - national gallery of art
# - national museum galle
# - negombo
# - negombo lagoon
# - nelum pokuna theatre
# - nelung arts centre
# - nilaveli beach
# - nine arches bridge
# - nuwara eliya
# - nuwara eliya golf club
# - pearl bay
# - peradeniya
# - pidurangala rock
# - pigeon island
# - pinnawala
# - pinnawala elephant orphanage
# - polonnaruwa
# - polonnaruwa ancient city
# - ramboda falls
# - ravan ella waterfall
# - rekawa beach
# - ritigala
# - royal colombo golf club
# - ruhunu maha kataragama dewalaya
# - seetha eliya
# - seethawaka wet zone botanical gardens
# - sigiriya
# - sinharaja forest reserve
# - sri dalada maligawa
# - sri lanka planetarium
# - surathali ella
# - tangalle
# - tangalle beach
# - trincomalee
# - trincomalee harbour
# - udawalawe national park
# - unawatuna
# - unawatuna beach
# - uppuveli beach
# - velgam vehera buddhist temple
# - viharamahadevi park
# - wasgamuwa national park
# - wilpattu national park
# - yala national park
# - yapahuwa rock fortress
#
# Number of places only in 'places' dataset: 291
# Number of places only in bucket list: 54

# %%
places_only
# Out:
# {'aanda ella fall',
#  'aberdeen waterfall',
#  'alahana pirivena',
#  'alankuda casuarina beach',
#  'all saints church, galle church of ceylon',
#  'alupotha ella waterfall',
#  'aluthnuwara rajamaha viharaya , aluthnuwara',
#  'ambuluwawa biodiversity complex',
#  'ambuluwawa temple',
#  'anawilundawa wetland',
#  'angammedilla national park',
#  'anuradhapura new town',
#  'arankale buddhist monastery',
#  'archaeological museum mihintale',
#  'archaeology museum kotte',
#  'arthurs seat view point, kandy',
#  'arukuveli beach',
#  'athugala viharaya',
#  'auslink hotel walapane sri lanka',
#  'balana fort',
#  'baobab tree pallimunai, mannar, sri lanka',
#  'batadombalena',
#  'bathalagoda tank',
#  'batticaloa dutch fort',
#  'batticaloa gate',
#  'batticaloa lagoon',
#  'batticaloa lighthouse',
#  'belilena cave',
#  'bentota ganga',
#  'bird watching tower',
#  'black galle fort zwart bastion',
#  'blue moon camping',
#  'boat trip kalpitiya dolphin watching',
#  'bogoda raja maha viharaya',
#  'bowatenna reservoir',
#  'box stone pettigala',
#  'british queens house',
#  'buddhangala raja maha viharaya',
#  'chariot path',
#  'chundikulam bird sanctuary',
#  'cinnamon bentota beach',
#  'colombo lotus tower',
#  'coral sanctuary boat ticket issue center',
#  'corbetts gap',
#  'council chamber',
#  'crocodile lake panama',
#  'dakkhina stupa anuradhapura',
#  'dalada maluva polonnaruwa',
#  'deegavapi maha stupa',
#  'deegawapi raja maha vihara',
#  'dehiwala zoological gardens',
#  'deliwala kota vehera temple',
#  'dematamal viharaya',
#  'dhanaja gem museum',
#  'dhushan ella',
#  'diggala campaign side',
#  'dimbulana hills spot',
#  'dimiyawa view point',
#  'divulgaskada kuda wewa',
#  'diyagala escape',
#  'diyatha uyana',
#  'diyawatanalla waterfall',
#  'dry zone botanic gardens, hambantota',
#  'dutch bay beach',
#  'dutch cannon',
#  'dutch fort jaffna',
#  'dutch reformed church, matara',
#  'duwili ella waterfall',
#  'elephant park',
#  'elephant point beach',
#  'ella rock trailhead',
#  'fort dew guest house and restaurant',
#  'fort entrance old gate',
#  'fort frederick',
#  'gal oya valley national park',
#  'galabedda biso pond',
#  'galegama wewa',
#  'galle fort attractions and jumpers sri lanka',
#  'geradi ella falls',
#  'glassaugh falls',
#  'haliela , sri lanka',
#  'hambantota beach',
#  'hatadage',
#  'hatale mini worlds end',
#  'hathbamba ella waterfall',
#  'hathbili ella falls',
#  'hettipola wewa',
#  'heyna camping site',
#  'hidden water fall tiny ella',
#  'hikka tranz by cinnamon',
#  'hirigalketiya waterfall',
#  'huluganga ella waterfall',
#  'hundukata',
#  'hunnasgiriya water fall',
#  'hurulu eco park wild elephant safari',
#  'ice fall view point',
#  'independence memorial museum',
#  'international buddhist museum',
#  'isurumuniya temple',
#  'jaffna lagoon area',
#  'jana kala kendraya',
#  'jayanthi wewa hot spring',
#  'jungle muru safari',
#  'kadawatha wewa',
#  'kalametiya bird sanctuary bird watching ecotourism',
#  'kalmunai point',
#  'kalpitiya dutch church',
#  'kanakarayan kulam',
#  'kandy lake view point',
#  'kandyan cultural centre',
#  'kanniya hot water springs',
#  'kataragama',
#  'kattukkarai kulam',
#  'katugas ella waterfall',
#  'katukeliyawa wewa',
#  'kelaniya raja maha viharaya',
#  'king sangiliyans statue',
#  'kiranchi beach',
#  'kiri vehera',
#  'kirindi ella waterfall',
#  'kiriwalketiya waterfall',
#  'knuckles forest reserve',
#  'koggala',
#  'kokkilai beach',
#  'korathota royal temple',
#  'kotte rajamaha vihara',
#  'kuda meegaskada wewa',
#  'kudawa beach kalpitiya',
#  'lahugala magul maha viharaya',
#  'lake side cabana',
#  'lankavatara beach',
#  'limestone caves',
#  'lions mouth rock kadugannawa',
#  'lissana gala',
#  'lotus pond ancient nelum pokuna',
#  'lotus pond nelum pokuna ii ii',
#  'lunuganga',
#  'madola ella',
#  'madu ganga',
#  'maha meegaskada wewa',
#  'maha viharaya, anuradhapura',
#  'mahakarambewa wewa',
#  'mahamevnawa buddhist monastery galle',
#  'mahamevnawa buddhist monastery polgahawela',
#  'makandawa conservation center makandawa forest',
#  'maligawila buddha statue',
#  'mandathivu beach',
#  'manelwatta temple',
#  'mannar dutch fort',
#  'marakolliya',
#  'mayan water park',
#  'mekichchawa wewa',
#  'menik ganga dunhinda falls',
#  'midigama right',
#  'millella small waterfall',
#  'mirisawetiya',
#  'mirissa',
#  'mirissa whale explorers',
#  'monument of victory',
#  'moon plains',
#  'mullaitivu beach',
#  'muthiyangana raja maha vihara',
#  'n uyana forest monastery',
#  'nanu oya water falls, nanu oya',
#  'narangala golden mountain',
#  'narangala n view point',
#  'national railway museum',
#  'national shrine of our lady of madhu',
#  'national spice garden of sri lanka',
#  'nawanalla waterfall',
#  'neithal eco park mandaitivu',
#  'neithal park',
#  'neluwa doovili ella',
#  'new kallady bridge batticaloa',
#  'new kallady bridge view point',
#  'nilavarai, natural underground water well , ,',
#  'nissanka lata mandapa',
#  'nuraicholai casuarina beach , kasakale',
#  'nuwara eliya mountains view point',
#  'nuwara wewa view point',
#  'okanda beach',
#  'our lady of refuge olr church, jaffna',
#  'paduwasnuwara museum',
#  'palace of king nishshanka malla',
#  'pallikuda beach',
#  'palugollewa wewa',
#  'panakala lagoon',
#  'panama wewa',
#  'pandalawa ella',
#  'panduwasnuwara kingdom',
#  'parakrama samudraya',
#  'parappudva island temple',
#  'paravagale ampara',
#  'pareiyan ella falls',
#  'parewi duwa temple',
#  'pasikuda beach',
#  'peacocks rock',
#  'pesalai beach',
#  'piduruthalagala conservation forest',
#  'pitawala nature trail',
#  'pitawala patana trail',
#  'polonnaruwa sivan kovil',
#  'porawagala viewpoint',
#  'port city colombo',
#  'potgul temple',
#  'pudumala camp site',
#  'rajanawa waterfall',
#  'ram setu',
#  'ranmasu uyana royal park',
#  'rathmalwetiya wewa',
#  'ravanas cave',
#  'rawana abyss',
#  'riapla mask museum',
#  'richmond castle',
#  'ridiyagama safari park',
#  'ridiyagama waterfront',
#  'rillamba surf point',
#  'ritigala strict natural reserve',
#  'riverston',
#  'royal botanic gardens, peradeniya',
#  'royal palace of king maha parakramabahu',
#  'royal palace park',
#  'ruins of an ancient building',
#  'ruins of poonakary fort',
#  'rumassala',
#  'rumassala south beach',
#  'ruwanweli maha seya',
#  'samadhi buddha statue',
#  'sambodhi pagoda temple',
#  'sandaraja wana arana',
#  'sangupiddi bridge',
#  'sathmahal prasadaya',
#  'sayansi beach',
#  'sea turtle hatchery habaraduwa',
#  'single tree hill',
#  'sinharaja rain forest, waddagala, kalawana',
#  'siri gautama sambuddharaja maligawa',
#  'snake farm weligama traditional farm',
#  'somawathiya national park',
#  'spa ceylon heritage spa boutique ii galle fort',
#  'sr vijayrma ancient temple',
#  'sri pada adams peak',
#  'sripada peak wilderness sanctuary',
#  'st. anthonys shrine, kochchikade.',
#  'st. clair falls',
#  'st. marys cathedral',
#  'st. marys cathedral jaffna',
#  'st. marys church',
#  'star gate ranmasu uyana',
#  'sundaram beach',
#  'sunflower arts crafts',
#  'sunsetisland',
#  'swarnagiri maha viharaya single tree temple',
#  'swastha ayurveda',
#  'talaimannar lighthouse',
#  'tantirimale rajamaha viharaya',
#  'thabbowa wewa view point',
#  'thalawila beach',
#  'thambiluvil beach',
#  'thandiyadi lagoon',
#  'the shrine of our lady of matara',
#  'thepulangoda waterfall',
#  'thummulla wewa',
#  'thuparama image house image of boddhisathwa',
#  'thuparamaya',
#  'tissamaharama raja maha vihara',
#  'tour with dash',
#  'trincomalee beach',
#  'turtle watch rekawa',
#  'turtle watching point',
#  'udawalawa',
#  'udawatta kele sanctuary',
#  'uduwathura lake',
#  'umari lagoon',
#  'upper diyaluma waterfall',
#  'uppuveli',
#  'ussangoda national park',
#  'vankalai bird sanctuary',
#  'vankalaippadu beach',
#  'vatadage',
#  'ventura beach',
#  'victor hasselblad sea turtle research and conservation centre',
#  'watawala ella',
#  'water world aquarium',
#  'wedikkarayage wewa',
#  'weherahena poorwarama rajamaha viharaya matara',
#  'weli oya bridge',
#  'weligama beach surf and stay',
#  'windmill',
#  'wirawila tissa sanctuary',
#  'yala green safari'}

# %%
bucket_only
# Out:
# {'ambalangoda mask workshop',
#  'ambuluwawa tower',
#  'anawilundawa wetlands',
#  'anuradapura',
#  'anuradhapura',
#  'arankelle forest monastery',
#  'batadombalena craft centre',
#  'batatotalena (batadombalena) cave',
#  'belilena caves',
#  'bentota',
#  'bentota beach',
#  'bentota river',
#  'colombo',
#  'colombo port city',
#  'dry zone botanic gardens',
#  'ella',
#  'ella gap',
#  'ella rock',
#  'excel world',
#  'folk museum',
#  'galle city tour',
#  'galle fort',
#  'hambantota',
#  'hatton',
#  'hikkaduwa coral sanctuary',
#  'hiriketiya',
#  'horton plains',
#  'kandy temple',
#  'kanniya hot springs',
#  'kithulgala',
#  'kitugala forest',
#  'kosgoda turtle hatchery',
#  'madu river',
#  'mahalenama cave',
#  'mahapelessa hot springs',
#  'museum of modern and contemporary art',
#  'nallur kandaswamy kovil',
#  'negambo',
#  'passikuda beach',
#  'perl bay',
#  'polonaruwa',
#  'ratnapura gem museum',
#  'riverstone gap',
#  'royal botanical gardens',
#  'sri pada / adams peak',
#  'st clairs falls',
#  'udawalawe',
#  'unawatuna lagoon',
#  'vaddha village camping',
#  'victoria golf club',
#  'water world lanka',
#  'wavulpone cave',
#  'weligama beach',
#  'weligama beach (surf and stay)'}

# %%
def find_similar_places(source_places, target_places, threshold=90):
    similar_places = {}
    for place in source_places:
        matches = process.extractBests(place, target_places, score_cutoff=threshold, limit=3)
        if matches:
            similar_places[place] = matches
    return similar_places

# Convert sets to lists for fuzzywuzzy
places_only_list = list(places_only)
bucket_only_list = list(bucket_only)

# Find similar places with similarity > 90%
similar_places = find_similar_places(places_only_list, bucket_only_list, threshold=90)

# Print results
print("Similar places (not exactly same) between places_only and bucket_only with similarity > 90%:")
for place, matches in similar_places.items():
    print(f"\nSimilar to '{place}':")
    for match in matches:
        print(f"  - '{match[0]}' (similarity: {match[1]}%)")

# Print summary
print(f"\nTotal number of places in places_only with similar matches (>90% similarity): {len(similar_places)}")
# Out:
# Similar places (not exactly same) between places_only and bucket_only with similarity > 90%:
#
# Similar to 'hidden water fall tiny ella':
#   - 'ella' (similarity: 90%)
#
# Similar to 'port city colombo':
#   - 'colombo port city' (similarity: 95%)
#   - 'colombo' (similarity: 90%)
#
# Similar to 'duwili ella waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'madola ella':
#   - 'ella' (similarity: 90%)
#
# Similar to 'maha viharaya, anuradhapura':
#   - 'anuradhapura' (similarity: 90%)
#
# Similar to 'spa ceylon heritage spa boutique ii galle fort':
#   - 'galle fort' (similarity: 90%)
#
# Similar to 'kirindi ella waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'riverston':
#   - 'riverstone gap' (similarity: 90%)
#
# Similar to 'pasikuda beach':
#   - 'passikuda beach' (similarity: 97%)
#
# Similar to 'neluwa doovili ella':
#   - 'ella' (similarity: 90%)
#
# Similar to 'dry zone botanic gardens, hambantota':
#   - 'dry zone botanic gardens' (similarity: 90%)
#   - 'hambantota' (similarity: 90%)
#
# Similar to 'huluganga ella waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'aanda ella fall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'weligama beach surf and stay':
#   - 'weligama beach (surf and stay)' (similarity: 98%)
#   - 'weligama beach' (similarity: 90%)
#
# Similar to 'colombo lotus tower':
#   - 'colombo' (similarity: 90%)
#
# Similar to 'anawilundawa wetland':
#   - 'anawilundawa wetlands' (similarity: 98%)
#
# Similar to 'millella small waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'sri pada adams peak':
#   - 'sri pada / adams peak' (similarity: 95%)
#
# Similar to 'ella rock trailhead':
#   - 'ella' (similarity: 90%)
#   - 'ella rock' (similarity: 90%)
#
# Similar to 'katugas ella waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'hathbamba ella waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'pandalawa ella':
#   - 'ella' (similarity: 90%)
#
# Similar to 'galle fort attractions and jumpers sri lanka':
#   - 'galle fort' (similarity: 90%)
#
# Similar to 'batadombalena':
#   - 'batadombalena craft centre' (similarity: 90%)
#   - 'batatotalena (batadombalena) cave' (similarity: 90%)
#
# Similar to 'watawala ella':
#   - 'ella' (similarity: 90%)
#
# Similar to 'dhushan ella':
#   - 'ella' (similarity: 90%)
#
# Similar to 'hathbili ella falls':
#   - 'ella' (similarity: 90%)
#
# Similar to 'pareiyan ella falls':
#   - 'ella' (similarity: 90%)
#
# Similar to 'dakkhina stupa anuradhapura':
#   - 'anuradhapura' (similarity: 90%)
#
# Similar to 'bentota ganga':
#   - 'bentota' (similarity: 90%)
#
# Similar to 'st. clair falls':
#   - 'st clairs falls' (similarity: 93%)
#
# Similar to 'kanniya hot water springs':
#   - 'kanniya hot springs' (similarity: 95%)
#
# Similar to 'hambantota beach':
#   - 'hambantota' (similarity: 90%)
#
# Similar to 'belilena cave':
#   - 'belilena caves' (similarity: 96%)
#
# Similar to 'anuradhapura new town':
#   - 'anuradhapura' (similarity: 90%)
#
# Similar to 'alupotha ella waterfall':
#   - 'ella' (similarity: 90%)
#
# Similar to 'geradi ella falls':
#   - 'ella' (similarity: 90%)
#
# Similar to 'cinnamon bentota beach':
#   - 'bentota' (similarity: 90%)
#   - 'bentota beach' (similarity: 90%)
#
# Similar to 'black galle fort zwart bastion':
#   - 'galle fort' (similarity: 90%)
#
# Total number of places in places_only with similar matches (>90% similarity): 39

# %% [markdown]
# ##### Notes:
# * Looks like there is a notable number of differences in places in two datasets. We need to look into this in the later parts.

# %%
sorted_activities = [activity.replace('safaris', 'wild life safaris').replace('hot air ballooning', 'air ballooning') for activity in sorted_activities]
sorted_activities
# Out:
# ['amusement parks',
#  'animal encounters',
#  'archaeological sites',
#  'architecture photography',
#  'architecture tours',
#  'art classes',
#  'arts and culture',
#  'ayurvedic spa treatments',
#  'beach visits',
#  'beachfront dining',
#  'bird watching',
#  'boat wild life safaris',
#  'botanical gardens',
#  'butterfly watching',
#  'camping',
#  'caving',
#  'city tours',
#  'craft workshops',
#  'cultural experiences',
#  'cultural festivals',
#  'cycling',
#  'elephant rides',
#  'fishing',
#  'golfing',
#  'hiking',
#  'historic sites',
#  'historic walks',
#  'historical monuments',
#  'history tours',
#  'horse shows',
#  'horseback riding',
#  'air ballooning',
#  'hot springs',
#  'kayaking',
#  'landscape photography',
#  'literary tours',
#  'local crafts',
#  'mountain biking',
#  'museum visits',
#  'outdoor adventures',
#  'paddleboarding',
#  'photography',
#  'planetarium visits',
#  'public art installations',
#  'river cruises',
#  'rock climbing',
#  'wild life safaris',
#  'sailing',
#  'sailing lessons',
#  'scuba diving',
#  'sea cruises',
#  'sightseeing',
#  'snorkeling',
#  'spiritual retreats',
#  'surfing',
#  'tea tasting',
#  'temple pilgrimages',
#  'theater',
#  'themed parks',
#  'traditional ceremonies',
#  'turtle watching',
#  'village homestays',
#  'water parks',
#  'waterfalls',
#  'whale watching',
#  'wildlife viewing',
#  'yoga retreats',
#  'zip-lining']

# %% [markdown]
# ### Let's extract relevant activities and their corresponding satisfaction scores for each location

# %%
places_df['extracted_activities'] = None
places_df['activity_scores'] = None

# %%
key1 = "AIzaSyCpSOdFzbl8XUgib6gyH9huHlekUiAc5cY"
key2 = "AIzaSyDwKelXBe5yGeoyXneX8a0dN3hWEhrLJss"

# Configure the Google Generative AI
def configure_genai(key):
    genai.configure(api_key=key)
    generation_config = {
        "temperature": 0.7,
        "top_p": 0.9,
        "max_output_tokens": 1000,
        "response_mime_type": "text/plain",
    }
    return genai.GenerativeModel(
        model_name="gemini-1.5-flash",
        generation_config=generation_config,
    )

def extract_activities_and_scores(review, candidate_activities, model):
    prompt = f"Extract all the activities and their satisfaction scores from the following reviews: {review}. The activities should be from the following list: {candidate_activities}. Give the response in this format: Activity name(in lowercase as in the given list) - satisfaction score(0-5). If there are many activities, add them line by line in the same format. remove markdown syntaxs and don't add details that are not required."
    chat_session = model.start_chat(history=[])
    response = chat_session.send_message(prompt)
    return response.text

def parse_and_average_extracted_data(extracted_data):
    activity_scores = defaultdict(list)
    lines = extracted_data.strip().split('\n')
    
    for line in lines:
        if ' - ' in line:
            activity, score = line.split(' - ')
            activity = activity.strip()
            score = float(score.strip())
            activity_scores[activity].append(score)

    averaged_activities = []
    averaged_scores = []
    
    for activity, scores in activity_scores.items():
        averaged_activities.append(activity)
        averaged_scores.append(sum(scores) / len(scores))

    return averaged_activities, averaged_scores

# Process rows in batches of 10
batch_size = 10
total_rows = len(places_df)

for start_idx in range(0, total_rows, batch_size):
    end_idx = min(start_idx + batch_size, total_rows)
    
    # Alternate between keys
    current_key = key1 if (start_idx // batch_size) % 2 == 0 else key2
    model = configure_genai(current_key)
    
    for i in range(start_idx, end_idx):
        review = places_df.iloc[i]['latest_reviews']
        extracted_data = extract_activities_and_scores(review, sorted_activities, model)
        
        activities, scores = parse_and_average_extracted_data(extracted_data)
        
        places_df.at[i, 'extracted_activities'] = activities
        places_df.at[i, 'activity_scores'] = scores
        
        del activities, scores, review, extracted_data
    
    print(f"Processed rows {start_idx} to {end_idx-1}")
    
    # Add a delay between batches to avoid hitting rate limits
    if end_idx < total_rows:
        time.sleep(30)  # Wait for 60 seconds between batches
# Out:
# Processed rows 0 to 9
# Processed rows 10 to 19
# Processed rows 20 to 29
# Processed rows 30 to 39
# Processed rows 40 to 49
# Processed rows 50 to 59
# Processed rows 60 to 69
# Processed rows 70 to 79
# Processed rows 80 to 89
# Processed rows 90 to 99
# Processed rows 100 to 109
# Processed rows 110 to 119
# Processed rows 120 to 129
# Processed rows 130 to 139
# Processed rows 140 to 149
# Processed rows 150 to 159
# Processed rows 160 to 169
# Processed rows 170 to 179
# Processed rows 180 to 189
# Processed rows 190 to 199
# Processed rows 200 to 209
# Processed rows 210 to 219
# Processed rows 220 to 229
# Processed rows 230 to 239
# Processed rows 240 to 249
# Processed rows 250 to 259
# Processed rows 260 to 269
# Processed rows 270 to 279
# Processed rows 280 to 289
# Processed rows 290 to 299
# Processed rows 300 to 309
# Processed rows 310 to 319
# Processed rows 320 to 329
# Processed rows 330 to 339
# Processed rows 340 to 349
# Processed rows 350 to 359
# Processed rows 360 to 369
# Processed rows 370 to 379
# Processed rows 380 to 389
# Processed rows 390 to 394

# %% [markdown]
# ##### Notes:
# * We processed the places_df in batches of 10 rows to extract activities and their scores from the reviews.
# * We alternated between two gemini API keys (key1 and key2) to avoid hitting rate limits.
# * The extracted activities and their scores were stored in the 'extracted_activities' and 'activity_scores' columns of places_df.
#
# * We also experimented with an alternative method for extracting activities and scores using vector cosine similarity. However, this approach didn't yield sufficiently accurate results compared to the Gemini-based method described above. While the vector similarity method is computationally efficient, it lacks the contextual understanding provided by the language model. We ultimately decided to use the more accurate Gemini-based approach, despite its higher computational cost.

# %%
# # Set up logging
# logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')

# # Sample candidate activities
# candidate_activities = sorted_activities

# # Function to perform sentiment analysis and return a satisfaction score
# def sentiment_to_score(sentiment):
#     return round(((sentiment + 1) / 2) * 4 + 1, 2)

# # Function to extract specific part of review related to the activity
# def get_activity_context(review, activity):
#     sentences = re.split(r'(?<!\w\.\w.)(?<![A-Z][a-z]\.)(?<=\.|\?)\s', review)
#     activity_mentions = [sent for sent in sentences if fuzz.partial_ratio(activity.lower(), sent.lower()) > 80]
    
#     if activity_mentions:
#         return " ".join(activity_mentions)
#     else:
#         return review

# # Function to preprocess text
# def preprocess_text(text):
#     if not isinstance(text, str):
#         return ""
#     text = text.lower()
#     text = re.sub(r'[^\w\s]', '', text)
#     words = text.split()
#     stop_words = set(['the', 'a', 'an', 'in', 'on', 'at', 'to', 'for', 'of', 'and', 'is', 'are'])
#     return " ".join([word for word in words if word not in stop_words])

# # Function to extract activities and calculate satisfaction score
# def extract_activities_with_scores(review):
#     try:
#         if not isinstance(review, str) or len(review.strip()) == 0:
#             logging.warning(f"Invalid review: {review}")
#             return [candidate_activities[0]], [3.0]  # Default to first activity with neutral score

#         # Preprocess the review and candidate activities
#         preprocessed_review = preprocess_text(review)
#         preprocessed_activities = [preprocess_text(activity) for activity in candidate_activities]

#         # Combine the preprocessed review with the preprocessed candidate activities
#         documents = [preprocessed_review] + preprocessed_activities

#         # Convert the documents to TF-IDF vectors
#         vectorizer = TfidfVectorizer().fit_transform(documents)
#         vectors = vectorizer.toarray()

#         # Calculate cosine similarity between the review and each candidate activity
#         cosine_similarities = cosine_similarity(vectors[0:1], vectors[1:]).flatten()

#         # Get the indices of the top 3 activities
#         top_indices = cosine_similarities.argsort()[-3:][::-1]
#         top_activities = [candidate_activities[i] for i in top_indices]
        
#         # Extract satisfaction score for each activity based on review sentiment
#         activity_scores = []
#         for activity in top_activities:
#             # Get the specific part of the review that mentions the activity
#             activity_context = get_activity_context(review, activity)
            
#             # Analyze the sentiment for the extracted context
#             blob = TextBlob(activity_context)
#             sentiment = blob.sentiment.polarity
#             score = sentiment_to_score(sentiment)
#             activity_scores.append(score)

#         # Ensure at least one activity is returned
#         if not top_activities:
#             logging.warning(f"No activities found for review: {review[:100]}...")
#             return [candidate_activities[0]], [3.0]  # Default to first activity with neutral score

#         return top_activities, activity_scores
#     except Exception as e:
#         logging.error(f"Error processing review: {e}\nReview: {review[:100]}...")
#         return [candidate_activities[0]], [3.0]  # Default to first activity with neutral score

# # Apply the function to the latest_reviews column with a progress bar
# tqdm.pandas(desc="Extracting activities and calculating scores for places")
# places_df['extracted_activities'], places_df['activity_scores'] = zip(*places_df['latest_reviews'].progress_apply(extract_activities_with_scores))

# # Ensure all places have at least one activity
# places_df['extracted_activities'] = places_df['extracted_activities'].apply(lambda x: x if len(x) > 0 else [candidate_activities[0]])
# places_df['activity_scores'] = places_df['activity_scores'].apply(lambda x: x if len(x) > 0 else [3.0])

# print(f"Places with no activities: {(places_df['extracted_activities'].apply(len) == 0).sum()}")
# print(f"Places with activities: {(places_df['extracted_activities'].apply(len) > 0).sum()}")

# %%
def weighted_rating(row, m=50, C=places_df['rating'].mean()):
    v = row['user_ratings_total']
    R = row['rating']
    return (v / (v + m) * R) + (m / (v + m) * C)

places_df['rating'] = places_df.apply(weighted_rating, axis=1)
places_df.drop(columns=['user_ratings_total'], inplace=True)

places_df.head(10)
# Out:
#                                           name       lat        lng  \
# 0                              Aanda Ella Fall  6.712021  80.460996
# 1                           Aberdeen Waterfall  6.949149  80.501514
# 2                                     Ahangama  5.973975  80.362159
# 3                                    Ahungalla  6.313278  80.040918
# 4                             Alahana Pirivena  7.961924  81.003995
# 5                     Alankuda Casuarina Beach  8.048135  79.709916
# 6    All Saints Church, Galle Church of Ceylon  6.027534  80.217448
# 7                      Alupotha Ella Waterfall  6.618278  80.409508
# 8  Aluthnuwara Rajamaha Viharaya , Aluthnuwara  7.227319  80.485243
# 9                                  Ambalangoda  6.244152  80.059080
#
#           formatted_address    rating  \
# 0                 Ratnapura  4.280646
# 1              Ginigathhena  4.790742
# 2                  Ahangama       NaN
# 3                 Ahungalla       NaN
# 4               Polonnaruwa  4.700491
# 5                 Kalpitiya  4.353584
# 6                     Galle  4.412032
# 7    Magurugoda Alupotha Rd  4.417349
# 8  Mawanella Aluthnuwara Rd  4.826857
# 9               Ambalangoda       NaN
#
#                                       latest_reviews  \
# 0  Aanda Ella Fall is a hidden gem The hike to th...
# 1  Aberdeen Waterfall is a stunning natural wonde...
# 2  Ahangama was a bit disappointing for me as a s...
# 3  Ahungalla seemed promising, but I found it a b...
# 4  Visiting Alahana Pirivena was a spiritual jour...
# 5  Alankuda Casuarina Beach is a hidden gem The p...
# 6  All Saints Church is a hidden gem in Galle The...
# 7  Alupotha Ella Waterfall is truly a gem The sou...
# 8  Visiting Aluthnuwara Rajamaha Viharaya was a s...
# 9  Ambalangoda had potential, but it fell short o...
#
#                                 extracted_activities  \
# 0                       [hiking, caving, waterfalls]
# 1                               [hiking, waterfalls]
# 2                            [surfing, beach visits]
# 3  [beach visits, beachfront dining, arts and cul...
# 4  [archaeological sites, historic sites, arts an...
# 5  [beach visits, beachfront dining, hiking, snor...
# 6  [architecture photography, arts and culture, h...
# 7                  [waterfalls, photography, hiking]
# 8  [architecture photography, architecture tours,...
# 9           [turtle watching, local crafts, fishing]
#
#                                      activity_scores
# 0                     [3.5, 3.6666666666666665, 3.0]
# 1                                         [3.8, 4.6]
# 2                                         [2.2, 3.2]
# 3           [2.5, 2.4, 2.0, 2.0, 2.0, 3.0, 2.0, 2.0]
# 4  [5.0, 5.0, 4.0, 4.0, 3.0, 3.0, 4.0, 4.0, 5.0, ...
# 5            [4.428571428571429, 3.0, 4.0, 4.0, 4.0]
# 6  [4.2, 4.166666666666667, 4.166666666666667, 4....
# 7                                    [4.0, 4.0, 4.0]
# 8  [3.6666666666666665, 3.6666666666666665, 3.5, ...
# 9  [2.8333333333333335, 2.1666666666666665, 1.333...

# %% [markdown]
# ##### Notes:
#
# * We implemented a weighted rating system to provide a more balanced and reliable rating for each place.
# * This approach combines the average rating with the number of ratings, giving more weight to places with a higher number of reviews. The formula used is known as the Bayesian average, which helps to mitigate the impact of places with very few ratings that might skew the results.

# %%
# Remove [, ], ', " signs in Preferred Activities and Bucket list destinations Sri Lanka
users_df['Preferred Activities'] = users_df['Preferred Activities'].str.replace(r"[\[\]'\"']", "", regex=True)
users_df['Bucket list destinations Sri Lanka'] = users_df['Bucket list destinations Sri Lanka'].str.replace(r"[\[\]'\"']", "", regex=True)

# %% [markdown]
# ##### Eliminating unnecessary features for future modeling

# %%
places_df.drop(columns=['latest_reviews'], inplace=True)
users_df.drop(columns=['Name'], inplace=True)
users_df.drop(columns=['User ID'], inplace=True)
users_df.drop(columns=['Email'], inplace=True)

# %% [markdown]
# ##### Saving final preprocessed datasets

# %%
users_df.to_csv('users_preprocessed.csv', index=False)

# %%
places_df.to_csv('places_preprocessed.csv', index=False)
